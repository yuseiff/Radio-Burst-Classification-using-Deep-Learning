# %% [markdown]
# ## Import the Modules

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from collections import Counter
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score
import tensorflow_hub as hub
from sklearn.linear_model import LogisticRegression
from seaborn import heatmap
from tensorflow.keras import layers, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model,Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import (
    VGG16, DenseNet121, MobileNet, MobileNetV2
)
from tensorflow.keras.layers import Flatten, Dense,Resizing

from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
# Out:
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Define constants
DATA_PATH = "radio bursts data"
IMG_SHAPE = (128, 128)
TEST_SPLIT = 0.2
NUM_CLASSES = 3
SEED = 42
os.makedirs('Weights', exist_ok=True)

# %%
# Utility Functions
def read_image(full_img_path):
    try:
        img = cv2.imread(full_img_path)
        return img
    except Exception as e:
        print(f"Warning: Error reading image '{full_img_path}': {e}")
        return None

# %%
def read_data(path, verbose=False, shape=IMG_SHAPE):
    images, labels, names = [], [], []
    for img_type in tqdm(os.listdir(path)):
        type_path = os.path.join(path, img_type)
        img_paths = [os.path.join(type_path, img) for img in os.listdir(type_path) if img.endswith('png')]

        with ThreadPoolExecutor() as executor:
            results = list(executor.map(read_image, img_paths))

        for img, img_path in zip(results, img_paths):
            if img is not None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert image to RGB
                img = cv2.resize(img, shape)
                images.append(img)
                labels.append(img_type)
                names.append(img_path)

        if verbose:
            print(f'Finished reading {len(img_paths)} images of type "{img_type}".')

    return np.array(images), np.array(names), np.array(labels)

# %%
def preprocess_spectrogram(data):
    median_values = np.median(data, axis=0)
    return data - median_values

# %% [markdown]
# ## Load and preprocess the dataset

# %%
# Load and preprocess data
images, paths, labels = read_data(DATA_PATH, verbose=False)
preprocessed_data = np.array([preprocess_spectrogram(img) for img in images])
# Out:
# 100%|██████████| 3/3 [00:40<00:00, 13.42s/it]

# %%
plt.imshow(images[1], aspect='auto', origin='lower')
plt.title('Noise')
plt.xlabel('Time')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.imshow(images[-1], aspect='auto', origin='lower')
plt.title('Type 3')
plt.xlabel('Time')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.imshow(images[700], aspect='auto', origin='lower')
plt.title('Type 2')
plt.xlabel('Time')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Data Preparation
X_train, X_test, y_train, y_test = train_test_split(preprocessed_data, labels, test_size=TEST_SPLIT, random_state=SEED)
label_encoder = {label: idx for idx, label in enumerate(np.unique(y_train))}

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0
y_train_encoded = np.array([label_encoder[label] for label in y_train])
y_test_encoded = np.array([label_encoder[label] for label in y_test])

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# ### Custome model

# %%
def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.5),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
input_shape = X_train.shape[1:]  # Shape after preprocessing
cnn_model = create_cnn_model(input_shape, NUM_CLASSES)
cnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train CNN Model
checkpoint = ModelCheckpoint('best_cnn_model.keras', monitor='val_accuracy', save_best_only=True)
cnn_model.fit(X_train, y_train_encoded, epochs=20, batch_size=32, validation_split=0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.4456 - loss: 1.1489 - val_accuracy: 0.6870 - val_loss: 0.7597
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 162ms/step - accuracy: 0.6870 - loss: 0.7337 - val_accuracy: 0.7590 - val_loss: 0.6670
# Epoch 3/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.7106 - loss: 0.6322 - val_accuracy: 0.7590 - val_loss: 0.6192
# Epoch 4/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.7471 - loss: 0.5629 - val_accuracy: 0.7784 - val_loss: 0.5331
# Epoch 5/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.7780 - loss: 0.4848 - val_accuracy: 0.8726 - val_loss: 0.3932
# Epoch 6/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8466 - loss: 0.3765 - val_accuracy: 0.8643 - val_loss: 0.3731
# Epoch 7/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - accuracy: 0.8786 - loss: 0.3478 - val_accuracy: 0.8837 - val_loss: 0.3688
# Epoch 8/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 0.9018 - loss: 0.2795 - val_accuracy: 0.9086 - val_loss: 0.2871
# Epoch 9/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.9003 - loss: 0.2647 - val_accuracy: 0.9030 - val_loss: 0.2699
# Epoch 10/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9247 - loss: 0.2171 - val_accuracy: 0.8560 - val_loss: 0.3226
# Epoch 11/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - accuracy: 0.9049 - loss: 0.2184 - val_accuracy: 0.8837 - val_loss: 0.3083
# Epoch 12/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.9164 - loss: 0.2188 - val_accuracy: 0.9141 - val_loss: 0.2457
# Epoch 13/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9424 - loss: 0.1455 - val_accuracy: 0.9030 - val_loss: 0.2555
# Epoch 14/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - accuracy: 0.9676 - loss: 0.0986 - val_accuracy: 0.9003 - val_loss: 0.2671
# Epoch 15/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9463 - loss: 0.1200 - val_accuracy: 0.9086 - val_loss: 0.2713
# Epoch 16/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9610 - loss: 0.1018 - val_accuracy: 0.9086 - val_loss: 0.2962
# Epoch 17/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9737 - loss: 0.0753 - val_accuracy: 0.9114 - val_loss: 0.2487
# Epoch 18/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 169ms/step - accuracy: 0.9756 - loss: 0.0725 - val_accuracy: 0.9197 - val_loss: 0.2919
# Epoch 19/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9779 - loss: 0.0720 - val_accuracy: 0.9086 - val_loss: 0.2965
# Epoch 20/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9736 - loss: 0.0761 - val_accuracy: 0.9086 - val_loss: 0.2751

# %%
# Evaluate CNN Model
cnn_model = load_model('best_cnn_model.keras')
train_loss, train_accuracy = cnn_model.evaluate(X_train, y_train_encoded)
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test_encoded)
print(f"Train Accuracy: {train_accuracy * 100:.2f}%")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Save model weights
cnn_model.save_weights('Weights\cnn_model.weights.h5')
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9873 - loss: 0.0417
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9215 - loss: 0.2982
# Train Accuracy: 97.39%
# Test Accuracy: 90.91%

# %%
test_pred=cnn_model.predict(X_test)
sns.heatmap(confusion_matrix(y_test_encoded,np.argmax(test_pred,axis=1)),annot=True)
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step

# %% [markdown]
# ### Pretrained Models

# %%
# Pretrained Models Setup
pretrained_models = {
    'VGG16': VGG16,
    'DenseNet121': DenseNet121,
    'MobileNet': MobileNet,
    'MobileNetV2': MobileNetV2
}

# %%
# Transfer Learning Function
def create_pretrained_model(model_class, input_shape, num_classes):
    base_model = model_class(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False
    model = Sequential([
        base_model,
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
# Cross-Validation with Pretrained Models
cv_results = {model_name: [] for model_name in pretrained_models.keys()}

for model_name, model_class in pretrained_models.items():
    print(f"Running K-Fold CV for {model_name}...")
    kf = KFold(n_splits=5, shuffle=True, random_state=SEED)
    
    for train_idx, val_idx in kf.split(X_train):
        X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
        y_train_fold, y_val_fold = y_train_encoded[train_idx], y_train_encoded[val_idx]
        
        model = create_pretrained_model(model_class, input_shape, NUM_CLASSES)
        model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        checkpoint = ModelCheckpoint(f'{model_name}_best.keras', monitor='val_accuracy', save_best_only=True)
        
        model.fit(X_train_fold, y_train_fold, epochs=10, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[checkpoint])
        best_model = load_model(f'{model_name}_best.keras')
        _, accuracy = best_model.evaluate(X_val_fold, y_val_fold)
        cv_results[model_name].append(accuracy)
# Out:
# Running K-Fold CV for VGG16...
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 949ms/step - accuracy: 0.5642 - loss: 1.1372 - val_accuracy: 0.7562 - val_loss: 0.5636
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 907ms/step - accuracy: 0.8091 - loss: 0.4987 - val_accuracy: 0.8476 - val_loss: 0.4251
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 935ms/step - accuracy: 0.8253 - loss: 0.4731 - val_accuracy: 0.8144 - val_loss: 0.4270
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 997ms/step - accuracy: 0.8399 - loss: 0.4097 - val_accuracy: 0.8864 - val_loss: 0.3637
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 968ms/step - accuracy: 0.8994 - loss: 0.3114 - val_accuracy: 0.8532 - val_loss: 0.3864
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 979ms/step - accuracy: 0.8996 - loss: 0.2731 - val_accuracy: 0.8837 - val_loss: 0.3196
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 994ms/step - accuracy: 0.8927 - loss: 0.2872 - val_accuracy: 0.8975 - val_loss: 0.3006
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 988ms/step - accuracy: 0.8963 - loss: 0.2837 - val_accuracy: 0.9003 - val_loss: 0.3211
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 964ms/step - accuracy: 0.9067 - loss: 0.2489 - val_accuracy: 0.8920 - val_loss: 0.2985
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 995ms/step - accuracy: 0.8860 - loss: 0.2969 - val_accuracy: 0.9058 - val_loss: 0.2976
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 740ms/step - accuracy: 0.8976 - loss: 0.3219
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.5950 - loss: 1.1177 - val_accuracy: 0.8089 - val_loss: 0.5047
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.7523 - loss: 0.5752 - val_accuracy: 0.8643 - val_loss: 0.3986
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 995ms/step - accuracy: 0.8381 - loss: 0.4188 - val_accuracy: 0.8670 - val_loss: 0.3721
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 965ms/step - accuracy: 0.8451 - loss: 0.4078 - val_accuracy: 0.8560 - val_loss: 0.3385
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8712 - loss: 0.3473 - val_accuracy: 0.8920 - val_loss: 0.2990
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 973ms/step - accuracy: 0.8947 - loss: 0.2933 - val_accuracy: 0.8837 - val_loss: 0.2894
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9144 - loss: 0.2717 - val_accuracy: 0.8920 - val_loss: 0.2764
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8911 - loss: 0.2769 - val_accuracy: 0.9003 - val_loss: 0.2675
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 974ms/step - accuracy: 0.8930 - loss: 0.2911 - val_accuracy: 0.8864 - val_loss: 0.2813
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 992ms/step - accuracy: 0.9191 - loss: 0.2346 - val_accuracy: 0.9030 - val_loss: 0.2772
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 736ms/step - accuracy: 0.9030 - loss: 0.2450
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.5415 - loss: 1.2533 - val_accuracy: 0.8611 - val_loss: 0.4346
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 989ms/step - accuracy: 0.8065 - loss: 0.4954 - val_accuracy: 0.8361 - val_loss: 0.3702
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 991ms/step - accuracy: 0.8254 - loss: 0.4196 - val_accuracy: 0.9083 - val_loss: 0.3225
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 981ms/step - accuracy: 0.8568 - loss: 0.3546 - val_accuracy: 0.9000 - val_loss: 0.3393
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 970ms/step - accuracy: 0.8819 - loss: 0.3309 - val_accuracy: 0.9278 - val_loss: 0.2679
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 925ms/step - accuracy: 0.8921 - loss: 0.2830 - val_accuracy: 0.9083 - val_loss: 0.2701
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 928ms/step - accuracy: 0.8898 - loss: 0.3074 - val_accuracy: 0.9167 - val_loss: 0.2667
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 928ms/step - accuracy: 0.9284 - loss: 0.2207 - val_accuracy: 0.9167 - val_loss: 0.2713
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 940ms/step - accuracy: 0.9070 - loss: 0.2351 - val_accuracy: 0.8528 - val_loss: 0.3487
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 966ms/step - accuracy: 0.8976 - loss: 0.2901 - val_accuracy: 0.9139 - val_loss: 0.2750
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 736ms/step - accuracy: 0.9418 - loss: 0.2372
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.5526 - loss: 1.1676 - val_accuracy: 0.7417 - val_loss: 0.5150
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 973ms/step - accuracy: 0.7740 - loss: 0.5331 - val_accuracy: 0.8917 - val_loss: 0.3544
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 972ms/step - accuracy: 0.8680 - loss: 0.3848 - val_accuracy: 0.8889 - val_loss: 0.3325
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 945ms/step - accuracy: 0.8538 - loss: 0.3718 - val_accuracy: 0.8972 - val_loss: 0.2706
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 946ms/step - accuracy: 0.9059 - loss: 0.2891 - val_accuracy: 0.9083 - val_loss: 0.2673
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 941ms/step - accuracy: 0.8899 - loss: 0.2884 - val_accuracy: 0.9194 - val_loss: 0.2460
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 919ms/step - accuracy: 0.8976 - loss: 0.2587 - val_accuracy: 0.9111 - val_loss: 0.2606
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 910ms/step - accuracy: 0.9212 - loss: 0.2234 - val_accuracy: 0.9083 - val_loss: 0.2406
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 914ms/step - accuracy: 0.8967 - loss: 0.2646 - val_accuracy: 0.9167 - val_loss: 0.2247
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 836ms/step - accuracy: 0.8988 - loss: 0.2677 - val_accuracy: 0.9139 - val_loss: 0.2341
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 667ms/step - accuracy: 0.9333 - loss: 0.2376
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 913ms/step - accuracy: 0.5920 - loss: 1.0468 - val_accuracy: 0.8972 - val_loss: 0.3919
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 874ms/step - accuracy: 0.8151 - loss: 0.4847 - val_accuracy: 0.8722 - val_loss: 0.3230
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 882ms/step - accuracy: 0.8421 - loss: 0.3835 - val_accuracy: 0.8833 - val_loss: 0.2858
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 877ms/step - accuracy: 0.8669 - loss: 0.3418 - val_accuracy: 0.8944 - val_loss: 0.2598
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 902ms/step - accuracy: 0.8949 - loss: 0.2820 - val_accuracy: 0.9111 - val_loss: 0.2240
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 897ms/step - accuracy: 0.8955 - loss: 0.2688 - val_accuracy: 0.9250 - val_loss: 0.2144
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 876ms/step - accuracy: 0.9218 - loss: 0.2368 - val_accuracy: 0.9083 - val_loss: 0.2347
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 871ms/step - accuracy: 0.8873 - loss: 0.2889 - val_accuracy: 0.9222 - val_loss: 0.2172
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 893ms/step - accuracy: 0.9035 - loss: 0.2533 - val_accuracy: 0.9333 - val_loss: 0.2046
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 878ms/step - accuracy: 0.8928 - loss: 0.2918 - val_accuracy: 0.8833 - val_loss: 0.2802
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 653ms/step - accuracy: 0.9293 - loss: 0.2155
# Running K-Fold CV for DenseNet121...
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 34s 522ms/step - accuracy: 0.5538 - loss: 4.0772 - val_accuracy: 0.7950 - val_loss: 0.5078
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 37s 429ms/step - accuracy: 0.7750 - loss: 0.5149 - val_accuracy: 0.8837 - val_loss: 0.3753
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 396ms/step - accuracy: 0.8254 - loss: 0.4142 - val_accuracy: 0.8781 - val_loss: 0.3677
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 403ms/step - accuracy: 0.8520 - loss: 0.3656 - val_accuracy: 0.8698 - val_loss: 0.3130
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 396ms/step - accuracy: 0.8589 - loss: 0.3311 - val_accuracy: 0.7950 - val_loss: 0.4785
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 20s 428ms/step - accuracy: 0.7951 - loss: 0.4938 - val_accuracy: 0.8975 - val_loss: 0.3158
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 405ms/step - accuracy: 0.7894 - loss: 0.4647 - val_accuracy: 0.8753 - val_loss: 0.3389
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 392ms/step - accuracy: 0.8057 - loss: 0.3948 - val_accuracy: 0.8670 - val_loss: 0.3998
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 20s 430ms/step - accuracy: 0.8069 - loss: 0.4100 - val_accuracy: 0.9114 - val_loss: 0.3021
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 399ms/step - accuracy: 0.8544 - loss: 0.3533 - val_accuracy: 0.9086 - val_loss: 0.3159
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 293ms/step - accuracy: 0.9105 - loss: 0.2841
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 519ms/step - accuracy: 0.5331 - loss: 3.3763 - val_accuracy: 0.8476 - val_loss: 0.4467
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 455ms/step - accuracy: 0.7982 - loss: 0.4924 - val_accuracy: 0.8532 - val_loss: 0.3938
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 450ms/step - accuracy: 0.8061 - loss: 0.4603 - val_accuracy: 0.8975 - val_loss: 0.3159
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 419ms/step - accuracy: 0.8694 - loss: 0.3272 - val_accuracy: 0.8615 - val_loss: 0.3545
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 424ms/step - accuracy: 0.8800 - loss: 0.3330 - val_accuracy: 0.8172 - val_loss: 0.4651
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 451ms/step - accuracy: 0.8229 - loss: 0.4325 - val_accuracy: 0.9030 - val_loss: 0.3054
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 420ms/step - accuracy: 0.8715 - loss: 0.3391 - val_accuracy: 0.8560 - val_loss: 0.3881
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - accuracy: 0.8589 - loss: 0.3480 - val_accuracy: 0.8975 - val_loss: 0.2748
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 422ms/step - accuracy: 0.8646 - loss: 0.2987 - val_accuracy: 0.8837 - val_loss: 0.3166
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 20s 434ms/step - accuracy: 0.8658 - loss: 0.3175 - val_accuracy: 0.8947 - val_loss: 0.2703
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 317ms/step - accuracy: 0.9192 - loss: 0.2722
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 597ms/step - accuracy: 0.5254 - loss: 3.2581 - val_accuracy: 0.8833 - val_loss: 0.3656
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 519ms/step - accuracy: 0.7957 - loss: 0.4887 - val_accuracy: 0.8917 - val_loss: 0.3210
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 520ms/step - accuracy: 0.8092 - loss: 0.4078 - val_accuracy: 0.9361 - val_loss: 0.2776
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 485ms/step - accuracy: 0.8210 - loss: 0.3992 - val_accuracy: 0.8833 - val_loss: 0.3154
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 484ms/step - accuracy: 0.8487 - loss: 0.4279 - val_accuracy: 0.9167 - val_loss: 0.2580
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 480ms/step - accuracy: 0.8791 - loss: 0.3070 - val_accuracy: 0.9194 - val_loss: 0.2874
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 480ms/step - accuracy: 0.8405 - loss: 0.3314 - val_accuracy: 0.9250 - val_loss: 0.2643
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 483ms/step - accuracy: 0.8401 - loss: 0.3564 - val_accuracy: 0.9222 - val_loss: 0.2730
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 481ms/step - accuracy: 0.8856 - loss: 0.2877 - val_accuracy: 0.9056 - val_loss: 0.2947
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 482ms/step - accuracy: 0.8627 - loss: 0.3127 - val_accuracy: 0.9333 - val_loss: 0.2423
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 353ms/step - accuracy: 0.9514 - loss: 0.2369
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 36s 578ms/step - accuracy: 0.5195 - loss: 2.3022 - val_accuracy: 0.8139 - val_loss: 0.4756
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 504ms/step - accuracy: 0.7437 - loss: 0.5992 - val_accuracy: 0.8194 - val_loss: 0.3955
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 515ms/step - accuracy: 0.7561 - loss: 0.5660 - val_accuracy: 0.8833 - val_loss: 0.3814
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 534ms/step - accuracy: 0.7685 - loss: 0.4730 - val_accuracy: 0.9000 - val_loss: 0.2859
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 495ms/step - accuracy: 0.8409 - loss: 0.3731 - val_accuracy: 0.8806 - val_loss: 0.3319
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 493ms/step - accuracy: 0.7925 - loss: 0.4355 - val_accuracy: 0.9000 - val_loss: 0.2850
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 497ms/step - accuracy: 0.7900 - loss: 0.4098 - val_accuracy: 0.8972 - val_loss: 0.3505
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 522ms/step - accuracy: 0.8146 - loss: 0.3854 - val_accuracy: 0.9028 - val_loss: 0.2664
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 497ms/step - accuracy: 0.8256 - loss: 0.3524 - val_accuracy: 0.9000 - val_loss: 0.2498
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 498ms/step - accuracy: 0.8584 - loss: 0.3135 - val_accuracy: 0.8944 - val_loss: 0.2688
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - accuracy: 0.9228 - loss: 0.2481
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 833ms/step - accuracy: 0.5691 - loss: 4.0832 - val_accuracy: 0.8944 - val_loss: 0.3885
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 28s 613ms/step - accuracy: 0.8205 - loss: 0.4522 - val_accuracy: 0.8778 - val_loss: 0.3170
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 883ms/step - accuracy: 0.8315 - loss: 0.4634 - val_accuracy: 0.8667 - val_loss: 0.3810
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 36s 781ms/step - accuracy: 0.8490 - loss: 0.3869 - val_accuracy: 0.8889 - val_loss: 0.3474
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.8078 - loss: 0.4969 - val_accuracy: 0.9139 - val_loss: 0.3046
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8784 - loss: 0.3092 - val_accuracy: 0.8639 - val_loss: 0.3810
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.8761 - loss: 0.3906 - val_accuracy: 0.8833 - val_loss: 0.3538
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9000 - loss: 0.2527 - val_accuracy: 0.9000 - val_loss: 0.2864
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9080 - loss: 0.2322 - val_accuracy: 0.9139 - val_loss: 0.2847
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9006 - loss: 0.2386 - val_accuracy: 0.9028 - val_loss: 0.2767
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 777ms/step - accuracy: 0.8891 - loss: 0.3791
# Running K-Fold CV for MobileNet...
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 353ms/step - accuracy: 0.6390 - loss: 2.6562 - val_accuracy: 0.8504 - val_loss: 0.3955
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 226ms/step - accuracy: 0.8505 - loss: 0.3787 - val_accuracy: 0.8560 - val_loss: 0.3636
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 254ms/step - accuracy: 0.8319 - loss: 0.4394 - val_accuracy: 0.8975 - val_loss: 0.3121
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 268ms/step - accuracy: 0.8741 - loss: 0.2863 - val_accuracy: 0.9003 - val_loss: 0.3295
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 212ms/step - accuracy: 0.8556 - loss: 0.3544 - val_accuracy: 0.8781 - val_loss: 0.4584
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.8872 - loss: 0.2486 - val_accuracy: 0.8920 - val_loss: 0.3073
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9189 - loss: 0.2116 - val_accuracy: 0.9141 - val_loss: 0.2920
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.9366 - loss: 0.1527 - val_accuracy: 0.9141 - val_loss: 0.3182
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.9328 - loss: 0.1581 - val_accuracy: 0.8864 - val_loss: 0.4154
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 268ms/step - accuracy: 0.9332 - loss: 0.1665 - val_accuracy: 0.9169 - val_loss: 0.3317
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - accuracy: 0.9133 - loss: 0.3191
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 307ms/step - accuracy: 0.7137 - loss: 1.5001 - val_accuracy: 0.8864 - val_loss: 0.2844
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.8699 - loss: 0.3463 - val_accuracy: 0.9114 - val_loss: 0.2200
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.9027 - loss: 0.2550 - val_accuracy: 0.9030 - val_loss: 0.2310
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 192ms/step - accuracy: 0.9065 - loss: 0.2185 - val_accuracy: 0.9141 - val_loss: 0.2432
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 191ms/step - accuracy: 0.9298 - loss: 0.1833 - val_accuracy: 0.9307 - val_loss: 0.2610
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.9246 - loss: 0.1932 - val_accuracy: 0.9030 - val_loss: 0.2728
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.9292 - loss: 0.1729 - val_accuracy: 0.9030 - val_loss: 0.2644
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.9506 - loss: 0.1288 - val_accuracy: 0.9114 - val_loss: 0.3080
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.9542 - loss: 0.1320 - val_accuracy: 0.9197 - val_loss: 0.2563
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.9371 - loss: 0.1961 - val_accuracy: 0.9141 - val_loss: 0.2566
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.9433 - loss: 0.2420
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 203ms/step - accuracy: 0.6339 - loss: 2.4209 - val_accuracy: 0.9056 - val_loss: 0.3375
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 163ms/step - accuracy: 0.8611 - loss: 0.3995 - val_accuracy: 0.9000 - val_loss: 0.2839
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.8653 - loss: 0.3204 - val_accuracy: 0.9194 - val_loss: 0.2403
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.8977 - loss: 0.2812 - val_accuracy: 0.9306 - val_loss: 0.2430
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.8932 - loss: 0.2719 - val_accuracy: 0.9278 - val_loss: 0.2426
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 217ms/step - accuracy: 0.9175 - loss: 0.1913 - val_accuracy: 0.9333 - val_loss: 0.2426
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 337ms/step - accuracy: 0.9323 - loss: 0.1727 - val_accuracy: 0.9306 - val_loss: 0.2467
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9155 - loss: 0.2087 - val_accuracy: 0.9417 - val_loss: 0.2392
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 264ms/step - accuracy: 0.9553 - loss: 0.1456 - val_accuracy: 0.9250 - val_loss: 0.2301
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.9566 - loss: 0.1098 - val_accuracy: 0.9139 - val_loss: 0.2894
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - accuracy: 0.9551 - loss: 0.1770
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 386ms/step - accuracy: 0.6403 - loss: 2.5494 - val_accuracy: 0.8667 - val_loss: 0.3478
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 356ms/step - accuracy: 0.8132 - loss: 0.4469 - val_accuracy: 0.8944 - val_loss: 0.2974
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.8776 - loss: 0.3210 - val_accuracy: 0.8972 - val_loss: 0.2501
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 332ms/step - accuracy: 0.9049 - loss: 0.2269 - val_accuracy: 0.8806 - val_loss: 0.3402
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 342ms/step - accuracy: 0.9215 - loss: 0.1980 - val_accuracy: 0.8944 - val_loss: 0.2561
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 365ms/step - accuracy: 0.9399 - loss: 0.1865 - val_accuracy: 0.9194 - val_loss: 0.2298
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 337ms/step - accuracy: 0.9340 - loss: 0.1660 - val_accuracy: 0.8972 - val_loss: 0.2618
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 343ms/step - accuracy: 0.9450 - loss: 0.1455 - val_accuracy: 0.9167 - val_loss: 0.2578
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - accuracy: 0.9564 - loss: 0.1132 - val_accuracy: 0.9167 - val_loss: 0.2515
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 361ms/step - accuracy: 0.9610 - loss: 0.1118 - val_accuracy: 0.9278 - val_loss: 0.2509
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.9350 - loss: 0.2151
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 20s 371ms/step - accuracy: 0.6411 - loss: 2.3031 - val_accuracy: 0.8861 - val_loss: 0.3020
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 314ms/step - accuracy: 0.8552 - loss: 0.3730 - val_accuracy: 0.8972 - val_loss: 0.2776
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 337ms/step - accuracy: 0.8882 - loss: 0.2846 - val_accuracy: 0.9194 - val_loss: 0.2446
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 324ms/step - accuracy: 0.9232 - loss: 0.2194 - val_accuracy: 0.9083 - val_loss: 0.2830
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 337ms/step - accuracy: 0.8968 - loss: 0.2913 - val_accuracy: 0.9056 - val_loss: 0.3350
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 309ms/step - accuracy: 0.9092 - loss: 0.2303 - val_accuracy: 0.9056 - val_loss: 0.2974
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.9344 - loss: 0.2063 - val_accuracy: 0.9167 - val_loss: 0.2813
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.9347 - loss: 0.1767 - val_accuracy: 0.9000 - val_loss: 0.2741
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - accuracy: 0.9332 - loss: 0.1625 - val_accuracy: 0.8806 - val_loss: 0.3105
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 310ms/step - accuracy: 0.9449 - loss: 0.1707 - val_accuracy: 0.9167 - val_loss: 0.3327
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - accuracy: 0.9042 - loss: 0.2664
# Running K-Fold CV for MobileNetV2...
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 400ms/step - accuracy: 0.6486 - loss: 3.4738 - val_accuracy: 0.8255 - val_loss: 0.4133
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.7941 - loss: 0.5057 - val_accuracy: 0.8587 - val_loss: 0.3746
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - accuracy: 0.8395 - loss: 0.3683 - val_accuracy: 0.8532 - val_loss: 0.4672
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - accuracy: 0.8317 - loss: 0.4027 - val_accuracy: 0.8560 - val_loss: 0.4140
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 362ms/step - accuracy: 0.8706 - loss: 0.3075 - val_accuracy: 0.8255 - val_loss: 0.4658
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 381ms/step - accuracy: 0.8719 - loss: 0.3058 - val_accuracy: 0.8809 - val_loss: 0.3583
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 354ms/step - accuracy: 0.8984 - loss: 0.2447 - val_accuracy: 0.9003 - val_loss: 0.3328
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 359ms/step - accuracy: 0.8854 - loss: 0.3152 - val_accuracy: 0.8726 - val_loss: 0.4799
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 367ms/step - accuracy: 0.8844 - loss: 0.2911 - val_accuracy: 0.8920 - val_loss: 0.3925
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 336ms/step - accuracy: 0.9142 - loss: 0.2290 - val_accuracy: 0.8920 - val_loss: 0.4111
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.8798 - loss: 0.3158
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 396ms/step - accuracy: 0.6120 - loss: 3.5331 - val_accuracy: 0.8310 - val_loss: 0.4185
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 356ms/step - accuracy: 0.8041 - loss: 0.4624 - val_accuracy: 0.8587 - val_loss: 0.3898
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 355ms/step - accuracy: 0.8512 - loss: 0.3707 - val_accuracy: 0.8726 - val_loss: 0.3589
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 355ms/step - accuracy: 0.8415 - loss: 0.3689 - val_accuracy: 0.8947 - val_loss: 0.3045
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.8795 - loss: 0.3053 - val_accuracy: 0.8670 - val_loss: 0.3894
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 337ms/step - accuracy: 0.8628 - loss: 0.3148 - val_accuracy: 0.8837 - val_loss: 0.3265
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.8859 - loss: 0.2962 - val_accuracy: 0.8753 - val_loss: 0.3138
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 353ms/step - accuracy: 0.8697 - loss: 0.2950 - val_accuracy: 0.9003 - val_loss: 0.3081
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 301ms/step - accuracy: 0.8933 - loss: 0.2787 - val_accuracy: 0.8809 - val_loss: 0.3374
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 334ms/step - accuracy: 0.8954 - loss: 0.2727 - val_accuracy: 0.8726 - val_loss: 0.3588
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - accuracy: 0.9144 - loss: 0.2864
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 389ms/step - accuracy: 0.6143 - loss: 3.3729 - val_accuracy: 0.8750 - val_loss: 0.3661
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 353ms/step - accuracy: 0.7849 - loss: 0.4742 - val_accuracy: 0.8389 - val_loss: 0.3442
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 368ms/step - accuracy: 0.8229 - loss: 0.3985 - val_accuracy: 0.9139 - val_loss: 0.2896
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - accuracy: 0.8357 - loss: 0.3337 - val_accuracy: 0.8722 - val_loss: 0.3160
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - accuracy: 0.8545 - loss: 0.3274 - val_accuracy: 0.8972 - val_loss: 0.2555
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 354ms/step - accuracy: 0.8683 - loss: 0.3335 - val_accuracy: 0.9139 - val_loss: 0.3056
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 365ms/step - accuracy: 0.8812 - loss: 0.3028 - val_accuracy: 0.9194 - val_loss: 0.2170
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 336ms/step - accuracy: 0.9050 - loss: 0.2716 - val_accuracy: 0.9167 - val_loss: 0.2552
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9019 - loss: 0.2516 - val_accuracy: 0.9167 - val_loss: 0.2430
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.9245 - loss: 0.2084 - val_accuracy: 0.9250 - val_loss: 0.2517
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9388 - loss: 0.2070
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 218ms/step - accuracy: 0.5872 - loss: 3.3754 - val_accuracy: 0.8500 - val_loss: 0.4079
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 192ms/step - accuracy: 0.8088 - loss: 0.4664 - val_accuracy: 0.8750 - val_loss: 0.3524
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.8346 - loss: 0.3857 - val_accuracy: 0.8833 - val_loss: 0.3338
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 193ms/step - accuracy: 0.8683 - loss: 0.3205 - val_accuracy: 0.8972 - val_loss: 0.2818
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.8783 - loss: 0.2740 - val_accuracy: 0.8833 - val_loss: 0.2889
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.8741 - loss: 0.3006 - val_accuracy: 0.8944 - val_loss: 0.3229
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.8980 - loss: 0.2459 - val_accuracy: 0.8444 - val_loss: 0.3649
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.9090 - loss: 0.2420 - val_accuracy: 0.8583 - val_loss: 0.3717
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 191ms/step - accuracy: 0.9239 - loss: 0.1908 - val_accuracy: 0.9000 - val_loss: 0.2557
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 189ms/step - accuracy: 0.9084 - loss: 0.2451 - val_accuracy: 0.9028 - val_loss: 0.3097
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9238 - loss: 0.2365
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 205ms/step - accuracy: 0.6196 - loss: 3.6019 - val_accuracy: 0.8389 - val_loss: 0.4053
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 188ms/step - accuracy: 0.8018 - loss: 0.4558 - val_accuracy: 0.8833 - val_loss: 0.3458
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 188ms/step - accuracy: 0.8580 - loss: 0.3478 - val_accuracy: 0.8972 - val_loss: 0.3104
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.8476 - loss: 0.3638 - val_accuracy: 0.8667 - val_loss: 0.3311
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 180ms/step - accuracy: 0.8894 - loss: 0.2892 - val_accuracy: 0.8833 - val_loss: 0.3412
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.9070 - loss: 0.2323 - val_accuracy: 0.8917 - val_loss: 0.3029
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - accuracy: 0.9073 - loss: 0.2445 - val_accuracy: 0.9111 - val_loss: 0.3312
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 179ms/step - accuracy: 0.8810 - loss: 0.2731 - val_accuracy: 0.9056 - val_loss: 0.3033
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.8751 - loss: 0.2905 - val_accuracy: 0.8806 - val_loss: 0.3499
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.8985 - loss: 0.2405 - val_accuracy: 0.9111 - val_loss: 0.3019
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.8843 - loss: 0.4027

# %%
# Calculate mean and std for CV accuracies and save to CSV
cv_summary = {
    'Model': [],
    'CV Accuracy (mean ± std)': []
}

# %%
for model_name, accuracies in cv_results.items():
    mean_acc = np.mean(accuracies)
    std_acc = np.std(accuracies)
    cv_summary['Model'].append(model_name)
    cv_summary['CV Accuracy (mean ± std)'].append(f"{mean_acc:.4f} ± {std_acc:.4f}")

# %%
cv_summary_df = pd.DataFrame(cv_summary)
cv_summary_df.to_csv('cv_summary.csv', index=False)

# %%
cv_summary_df
# Out:
#          Model CV Accuracy (mean ± std)
# 0        VGG16          0.9179 ± 0.0119
# 1  DenseNet121          0.9134 ± 0.0122
# 2    MobileNet          0.9273 ± 0.0088
# 3  MobileNetV2          0.9079 ± 0.0094

# %%
# Save cross-validation results to CSV
cv_results_df = pd.DataFrame(cv_results)
cv_results_df.to_csv('cv_results.csv', index=False)

# %% [markdown]
# ### Ensembles

# %% [markdown]
# #### Voting

# %%
# Soft Voting Ensemble
def soft_voting_ensemble(models, X):
    predictions = [model.predict(X) for model in models.values()]
    avg_predictions = np.mean(predictions, axis=0)
    return np.argmax(avg_predictions, axis=1)

# %%
models = {name: load_model(f'{name}_best.keras') for name in pretrained_models.keys()}
ensemble_predictions = soft_voting_ensemble(models, X_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 690ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 547ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step

# %%
ensemble_accuracy = accuracy_score(y_test_encoded, ensemble_predictions)
print(f"Ensemble Test Accuracy: {ensemble_accuracy * 100:.2f}%")
# Out:
# Ensemble Test Accuracy: 91.80%

# %%
sns.heatmap(confusion_matrix(y_test_encoded,ensemble_predictions),annot=True)
plt.show()

# %% [markdown]
# #### Stacking

# %%
# Stacking Ensemble
def get_stacking_data(models, X):
    return np.hstack([model.predict(X) for model in models.values()])

# %%
stacking_train_data = get_stacking_data(models, X_train)
stacking_test_data = get_stacking_data(models, X_test)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 703ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 22s 381ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 681ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step

# %%
meta_model = LogisticRegression(max_iter=1000)
meta_model.fit(stacking_train_data, y_train_encoded)
# Out:
# LogisticRegression(max_iter=1000)

# %%
stacking_predictions = meta_model.predict(stacking_test_data)
stacking_accuracy = accuracy_score(y_test_encoded, stacking_predictions)
print(f"Stacking Test Accuracy: {stacking_accuracy * 100:.2f}%")
# Out:
# Stacking Test Accuracy: 92.46%

# %%
sns.heatmap(confusion_matrix(y_test_encoded,stacking_predictions),annot=True)
plt.show()

# %% [markdown]
# ### Vision Transformers

# %% [markdown]
# #### Vit

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
class FlexibleViTModel(tf.keras.Model):
    def __init__(self, output_classes):
        super(FlexibleViTModel, self).__init__()
        self.resize = Resizing(224, 224)  # Resize inputs to 224x224
        self.vit_layer = hub.KerasLayer(
            "https://tfhub.dev/sayakpaul/vit_b16_fe/1", 
            trainable=False
        )
        self.flatten = Flatten()
        self.output_dense = Dense(output_classes, activation="softmax")

    def call(self, inputs):
        resized_inputs = self.resize(inputs)
        vit_output = self.vit_layer(resized_inputs)
        vit_output = self.flatten(vit_output)
        return self.output_dense(vit_output)

# %%
import os

cache_dir = "D:\\My Laptop\\Me\\Programming\\Machine Learning\\Internships\\Egyptian Space Agency\\Project\\tfhub_cache"
print("Writeable:", os.access(cache_dir, os.W_OK))

import shutil

# Clear the TensorFlow Hub cache
cache_dir = "D:\\My Laptop\\Me\\Programming\\Machine Learning\\Internships\\Egyptian Space Agency\\Project\\tfhub_cache"
shutil.rmtree(cache_dir, ignore_errors=True)
os.makedirs(cache_dir, exist_ok=True)
print("Cache cleared.")

import os

# Set a shorter cache directory
os.environ['TFHUB_CACHE_DIR'] = "d:\\tfhub_cache"
os.makedirs("d:\\tfhub_cache", exist_ok=True)
print("Shortened cache directory set.")
# Out:
# Writeable: True
# Cache cleared.
# Shortened cache directory set.

# %%
# Instantiate the model
input_layer = tf.keras.Input(shape=(128, 128, 3))
output_classes = len(label_encoder)
vit_model = FlexibleViTModel(output_classes)

outputs = vit_model(input_layer)

# Compile the model
final_model = Model(inputs=input_layer, outputs=outputs)
final_model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
vit_model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "flexible_vi_t_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_21 (Flatten)            │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 3)              │         2,307 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,307 (9.01 KB)
#  Trainable params: 2,307 (9.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',        # Monitor the validation loss
    patience=10,                # Wait for 10 epochs without improvement
    verbose=1,                 # Print a message when stopping
    restore_best_weights=True # Restore the best weights after stopping
)

# %%
history = final_model.fit(
    X_train, y_train_encoded, 
    validation_split=0.1, 
    batch_size=32,
    epochs=50,  # Set the maximum number of epochs
    callbacks=[early_stopping]  # Pass the early stopping callback here
)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 331s 6s/step - accuracy: 0.5802 - loss: 0.9945 - val_accuracy: 0.8343 - val_loss: 0.3668
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 280s 5s/step - accuracy: 0.8701 - loss: 0.3631 - val_accuracy: 0.8729 - val_loss: 0.3061
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - accuracy: 0.9097 - loss: 0.2743 - val_accuracy: 0.8729 - val_loss: 0.2806
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 285s 6s/step - accuracy: 0.8982 - loss: 0.2608 - val_accuracy: 0.9006 - val_loss: 0.2635
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 287s 6s/step - accuracy: 0.9128 - loss: 0.2397 - val_accuracy: 0.8840 - val_loss: 0.2639
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9095 - loss: 0.2205 - val_accuracy: 0.8950 - val_loss: 0.2485
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9412 - loss: 0.1847 - val_accuracy: 0.8895 - val_loss: 0.2453
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 290s 6s/step - accuracy: 0.9329 - loss: 0.2027 - val_accuracy: 0.8950 - val_loss: 0.2335
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 289s 6s/step - accuracy: 0.9194 - loss: 0.2031 - val_accuracy: 0.9061 - val_loss: 0.2184
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9341 - loss: 0.1838 - val_accuracy: 0.8950 - val_loss: 0.2237
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 293s 6s/step - accuracy: 0.9442 - loss: 0.1554 - val_accuracy: 0.9006 - val_loss: 0.2265
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9395 - loss: 0.1719 - val_accuracy: 0.9282 - val_loss: 0.2148
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9432 - loss: 0.1602 - val_accuracy: 0.9061 - val_loss: 0.2164
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 290s 6s/step - accuracy: 0.9515 - loss: 0.1460 - val_accuracy: 0.9061 - val_loss: 0.2091
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 293s 6s/step - accuracy: 0.9486 - loss: 0.1496 - val_accuracy: 0.9006 - val_loss: 0.2105
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9581 - loss: 0.1371 - val_accuracy: 0.8729 - val_loss: 0.2821
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 285s 6s/step - accuracy: 0.9450 - loss: 0.1530 - val_accuracy: 0.9171 - val_loss: 0.2178
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 329s 6s/step - accuracy: 0.9616 - loss: 0.1322 - val_accuracy: 0.8785 - val_loss: 0.2202
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 353s 7s/step - accuracy: 0.9603 - loss: 0.1305 - val_accuracy: 0.9282 - val_loss: 0.2030
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 305s 6s/step - accuracy: 0.9649 - loss: 0.1204 - val_accuracy: 0.9337 - val_loss: 0.1991
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 297s 6s/step - accuracy: 0.9480 - loss: 0.1420 - val_accuracy: 0.9061 - val_loss: 0.2099
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 300s 6s/step - accuracy: 0.9638 - loss: 0.1125 - val_accuracy: 0.9171 - val_loss: 0.2078
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 308s 6s/step - accuracy: 0.9680 - loss: 0.1069 - val_accuracy: 0.9171 - val_loss: 0.2038
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 294s 6s/step - accuracy: 0.9720 - loss: 0.1076 - val_accuracy: 0.9171 - val_loss: 0.2023
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 298s 6s/step - accuracy: 0.9558 - loss: 0.1193 - val_accuracy: 0.9116 - val_loss: 0.2108
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9614 - loss: 0.1207 - val_accuracy: 0.9282 - val_loss: 0.1987
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9682 - loss: 0.1038 - val_accuracy: 0.9282 - val_loss: 0.2055
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 290s 6s/step - accuracy: 0.9696 - loss: 0.0927 - val_accuracy: 0.9006 - val_loss: 0.2092
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 289s 6s/step - accuracy: 0.9573 - loss: 0.1208 - val_accuracy: 0.9227 - val_loss: 0.2003
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 289s 6s/step - accuracy: 0.9752 - loss: 0.0963 - val_accuracy: 0.9171 - val_loss: 0.2006
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 287s 6s/step - accuracy: 0.9731 - loss: 0.1003 - val_accuracy: 0.9282 - val_loss: 0.2202
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9643 - loss: 0.1032 - val_accuracy: 0.9227 - val_loss: 0.2073
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9779 - loss: 0.0797 - val_accuracy: 0.9337 - val_loss: 0.2008
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 287s 6s/step - accuracy: 0.9718 - loss: 0.0907 - val_accuracy: 0.9171 - val_loss: 0.2783
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 286s 6s/step - accuracy: 0.9464 - loss: 0.1386 - val_accuracy: 0.9227 - val_loss: 0.1986
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 286s 6s/step - accuracy: 0.9717 - loss: 0.0816 - val_accuracy: 0.9116 - val_loss: 0.2065
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 300s 6s/step - accuracy: 0.9766 - loss: 0.0800 - val_accuracy: 0.9227 - val_loss: 0.1978
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9759 - loss: 0.0803 - val_accuracy: 0.9282 - val_loss: 0.2078
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 303s 6s/step - accuracy: 0.9765 - loss: 0.0843 - val_accuracy: 0.9227 - val_loss: 0.2103
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9746 - loss: 0.0792 - val_accuracy: 0.9116 - val_loss: 0.2031
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 291s 6s/step - accuracy: 0.9856 - loss: 0.0702 - val_accuracy: 0.9227 - val_loss: 0.2252
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 286s 6s/step - accuracy: 0.9835 - loss: 0.0740 - val_accuracy: 0.8840 - val_loss: 0.2337
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 304s 6s/step - accuracy: 0.9635 - loss: 0.1011 - val_accuracy: 0.9171 - val_loss: 0.2575
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9750 - loss: 0.0852 - val_accuracy: 0.9116 - val_loss: 0.2119
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 287s 6s/step - accuracy: 0.9668 - loss: 0.0849 - val_accuracy: 0.9006 - val_loss: 0.2175
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 281s 6s/step - accuracy: 0.9741 - loss: 0.0852 - val_accuracy: 0.9227 - val_loss: 0.2062
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 293s 6s/step - accuracy: 0.9822 - loss: 0.0701 - val_accuracy: 0.9061 - val_loss: 0.2311
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %% [markdown]
# ##### Evaluate Vit

# %%
train_pred = np.argmax(final_model.predict(X_train),axis=1)
test_probabilities = final_model.predict(X_test) 
test_pred = np.argmax(test_probabilities,axis=1)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 343s 6s/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 87s 6s/step

# %%
Vit_train_accuracy = accuracy_score(y_train_encoded, train_pred)
Vit_test_accuracy = accuracy_score(y_test_encoded, test_pred)

# %%
print(f'vit_model train accuracy: {train_accuracy}')
print(f'vit_model test accuracy: {Vit_test_accuracy}')
# Out:
# vit_model train accuracy: 0.9739178419113159
# vit_model test accuracy: 0.8957871396895787

# %%
sns.heatmap(confusion_matrix(y_test_encoded,test_pred),annot=True)
plt.show()

# %%
final_model.save_weights(r'Weights\vit_model.weights.h5')

# %% [markdown]
# #### Swin

# %%
class SwinTransformerModel(tf.keras.Model):
    def __init__(self,output_classes):
        super(SwinTransformerModel, self).__init__()
        # Load the Swin Transformer model
        self.resize = Resizing(224, 224)
        self.swin_layer = hub.KerasLayer(
            "https://tfhub.dev/sayakpaul/swin_tiny_patch4_window7_224/1",
            trainable=False  # Set to True for fine-tuning
        )
        self.flatten = layers.Flatten()
        self.dense = layers.Dense(output_classes, activation='softmax')
    
    def call(self, input_tensor):
        resized_inputs = self.resize(input_tensor)
        swin_output = self.swin_layer(resized_inputs)
        swin_output = self.flatten(swin_output)
        return self.dense(swin_output)

# %%
input_layer = tf.keras.Input(shape=(128, 128, 3))
swin_model = SwinTransformerModel(output_classes)

output_layer = swin_model(input_layer)

swin_model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
swin_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
swin_model.summary()
# Out:
# Model: "functional_168"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_42 (InputLayer)     │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ swin_transformer_model          │ (None, 3)              │         3,003 │
# │ (SwinTransformerModel)          │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,003 (11.73 KB)
#  Trainable params: 3,003 (11.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_swin = swin_model.fit(
    X_train, y_train_encoded,
    validation_split=0.1,
    batch_size=32,
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 130s 2s/step - accuracy: 0.6083 - loss: 0.9104 - val_accuracy: 0.7790 - val_loss: 0.5765
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.8377 - loss: 0.4674 - val_accuracy: 0.8177 - val_loss: 0.4838
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.8696 - loss: 0.3748 - val_accuracy: 0.7403 - val_loss: 0.5276
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.8465 - loss: 0.3855 - val_accuracy: 0.8508 - val_loss: 0.4018
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.8856 - loss: 0.3052 - val_accuracy: 0.8122 - val_loss: 0.4298
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.8846 - loss: 0.2945 - val_accuracy: 0.8674 - val_loss: 0.3580
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.9038 - loss: 0.2788 - val_accuracy: 0.8398 - val_loss: 0.3536
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9178 - loss: 0.2722 - val_accuracy: 0.8343 - val_loss: 0.3508
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9144 - loss: 0.2515 - val_accuracy: 0.8785 - val_loss: 0.3265
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9146 - loss: 0.2484 - val_accuracy: 0.8674 - val_loss: 0.3239
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
swin_train_pred = np.argmax(swin_model.predict(X_train), axis=1)
swin_test_pred = np.argmax(swin_model.predict(X_test), axis=1)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step

# %%
swin_train_accuracy = accuracy_score(y_train_encoded, swin_train_pred)
swin_test_accuracy = accuracy_score(y_test_encoded, swin_test_pred)

# %%
print(f'swin_model train accuracy: {swin_train_accuracy}')
print(f'swin_model test accuracy: {swin_test_accuracy}')
# Out:
# swin_model train accuracy: 0.8263041065482797
# swin_model test accuracy: 0.7827050997782705

# %%
sns.heatmap(confusion_matrix(y_test_encoded, swin_test_pred), annot=True)
plt.show()

# %%
swin_model.save_weights(r'Weights\swin_model.weights.h5')

# %% [markdown]
# #### ConvNext

# %%
class ConvNextModel(tf.keras.Model):
    def __init__(self,output_classes):
        super(ConvNextModel, self).__init__()
        # Load ConvNext from TensorFlow Hub
        self.resize = Resizing(224, 224)
        self.convnext_layer = hub.KerasLayer(
            "https://www.kaggle.com/models/spsayakpaul/convnext/TensorFlow2/base-1k-224/1",
            trainable=False  # Set to True for fine-tuning
        )
        self.flatten = layers.Flatten()
        self.dense = layers.Dense(output_classes, activation='softmax')
    
    def call(self, input_tensor):
        resized_inputs = self.resize(input_tensor)
        convnext_output = self.convnext_layer(resized_inputs)
        convnext_output = self.flatten(convnext_output)
        return self.dense(convnext_output)

# %%
input_layer = tf.keras.Input(shape=(128, 128, 3))
convnext_model = ConvNextModel(output_classes)

output_layer = convnext_model(input_layer)

convnext_model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
convnext_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
convnext_model.summary()
# Out:
# Model: "functional_169"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_43 (InputLayer)     │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_next_model (ConvNextModel) │ (None, 3)              │         3,003 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,003 (11.73 KB)
#  Trainable params: 3,003 (11.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_convnext = convnext_model.fit(
    X_train, y_train_encoded,
    validation_split=0.1,
    batch_size=32,
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 252s 5s/step - accuracy: 0.5344 - loss: 1.0182 - val_accuracy: 0.7680 - val_loss: 0.6409
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 233s 5s/step - accuracy: 0.7790 - loss: 0.5800 - val_accuracy: 0.7624 - val_loss: 0.5536
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 234s 5s/step - accuracy: 0.8359 - loss: 0.4978 - val_accuracy: 0.7901 - val_loss: 0.5048
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 234s 5s/step - accuracy: 0.8325 - loss: 0.4691 - val_accuracy: 0.7901 - val_loss: 0.4933
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 234s 5s/step - accuracy: 0.8465 - loss: 0.4267 - val_accuracy: 0.8232 - val_loss: 0.4488
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 234s 5s/step - accuracy: 0.8582 - loss: 0.3986 - val_accuracy: 0.8177 - val_loss: 0.4537
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 235s 5s/step - accuracy: 0.8584 - loss: 0.4186 - val_accuracy: 0.8343 - val_loss: 0.4244
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 235s 5s/step - accuracy: 0.8714 - loss: 0.3785 - val_accuracy: 0.8398 - val_loss: 0.4104
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 235s 5s/step - accuracy: 0.8758 - loss: 0.3547 - val_accuracy: 0.8398 - val_loss: 0.4130
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 235s 5s/step - accuracy: 0.8720 - loss: 0.3746 - val_accuracy: 0.8287 - val_loss: 0.3960
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
convnext_train_pred = np.argmax(convnext_model.predict(X_train), axis=1)
convnext_test_pred = np.argmax(convnext_model.predict(X_test), axis=1)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 241s 4s/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 59s 4s/step

# %%
convnext_train_accuracy = accuracy_score(y_train_encoded, convnext_train_pred)
convnext_test_accuracy = accuracy_score(y_test_encoded, convnext_test_pred)

# %%
print(f'convnext_model train accuracy: {convnext_train_accuracy}')
print(f'convnext_model test accuracy: {convnext_test_accuracy}')
# Out:
# convnext_model train accuracy: 0.781354051054384
# convnext_model test accuracy: 0.738359201773836

# %%
sns.heatmap(confusion_matrix(y_test_encoded, convnext_test_pred), annot=True)
plt.show()

# %%
convnext_model.save_weights(r'Weights\convnext_model.weights.h5')

# %% [markdown]
# ### Compare the Results

# %%
# Save final results to CSV
results = {
    'Model': ['CNN', 'Voting', 'Stacking wt LR','Vit','Swin','Convnext'],
    'Test Accuracy': [test_accuracy, ensemble_accuracy, stacking_accuracy,Vit_test_accuracy,swin_test_accuracy,convnext_test_accuracy]
}

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('final_results.csv', index=False)
